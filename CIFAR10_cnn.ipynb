# %% [markdown]
# <a href="https://colab.research.google.com/github/oyyarko/keras_tut/blob/master/CIFAR10_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.python.keras.datasets import cifar10
import tensorflow.python.keras

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(x_train.shape[0])
print(x_test.shape[0])
# Out:
# 50000
# 10000

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20, 5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
from keras.utils import np_utils
import keras

num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

print('X Train shape: ',x_train.shape)

print(x_train.shape[0], 'X Train samples')
print(x_test.shape[0], 'X Test samples')
print(x_valid.shape[0], 'X Valid samples')
# Out:
# X Train shape:  (45000, 32, 32, 3)
# 45000 X Train samples
# 10000 X Test samples
# 5000 X Valid samples

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
from tensorflow.python.keras.callbacks import ModelCheckpoint

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)

hist = model.fit(x_train, y_train, batch_size = 32, epochs = 100, verbose=2, callbacks=[checkpointer], validation_data=(x_valid, y_valid), shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.73826, saving model to model.weights.best.hdf5
# 45000/45000 - 6s - loss: 1.8292 - acc: 0.3467 - val_loss: 1.7383 - val_acc: 0.3318
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.73826 to 1.68060, saving model to model.weights.best.hdf5
# 45000/45000 - 6s - loss: 1.8249 - acc: 0.3430 - val_loss: 1.6806 - val_acc: 0.3910
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.68060 to 1.64422, saving model to model.weights.best.hdf5
# 45000/45000 - 6s - loss: 1.8254 - acc: 0.3425 - val_loss: 1.6442 - val_acc: 0.3952
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.8395 - acc: 0.3427 - val_loss: 1.7484 - val_acc: 0.3308
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.8535 - acc: 0.3340 - val_loss: 1.8541 - val_acc: 0.2922
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.8764 - acc: 0.3268 - val_loss: 1.8653 - val_acc: 0.3430
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.8632 - acc: 0.3259 - val_loss: 1.8832 - val_acc: 0.3472
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.8815 - acc: 0.3177 - val_loss: 1.7806 - val_acc: 0.4224
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.8831 - acc: 0.3228 - val_loss: 1.7071 - val_acc: 0.3922
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.8900 - acc: 0.3183 - val_loss: 1.7346 - val_acc: 0.3560
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9020 - acc: 0.3059 - val_loss: 1.7555 - val_acc: 0.3666
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9404 - acc: 0.2962 - val_loss: 1.8338 - val_acc: 0.3698
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9362 - acc: 0.2908 - val_loss: 1.8852 - val_acc: 0.2886
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9201 - acc: 0.2964 - val_loss: 2.8032 - val_acc: 0.2938
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9318 - acc: 0.2928 - val_loss: 2.1821 - val_acc: 0.3598
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9330 - acc: 0.2932 - val_loss: 2.1262 - val_acc: 0.2428
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9318 - acc: 0.2907 - val_loss: 1.6697 - val_acc: 0.3594
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9324 - acc: 0.2860 - val_loss: 2.9983 - val_acc: 0.2316
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9230 - acc: 0.2881 - val_loss: 3.0216 - val_acc: 0.3162
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9510 - acc: 0.2816 - val_loss: 2.1096 - val_acc: 0.2632
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9392 - acc: 0.2799 - val_loss: 1.7516 - val_acc: 0.3426
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9470 - acc: 0.2816 - val_loss: 1.7533 - val_acc: 0.3448
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9427 - acc: 0.2782 - val_loss: 1.6776 - val_acc: 0.3766
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9494 - acc: 0.2788 - val_loss: 1.7553 - val_acc: 0.3276
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9459 - acc: 0.2804 - val_loss: 1.6920 - val_acc: 0.3910
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9411 - acc: 0.2730 - val_loss: 1.9570 - val_acc: 0.3558
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9504 - acc: 0.2796 - val_loss: 1.8795 - val_acc: 0.3376
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9516 - acc: 0.2753 - val_loss: 2.1047 - val_acc: 0.2548
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9499 - acc: 0.2714 - val_loss: 1.8399 - val_acc: 0.3528
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9425 - acc: 0.2717 - val_loss: 1.8563 - val_acc: 0.3114
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9676 - acc: 0.2682 - val_loss: 2.6144 - val_acc: 0.3250
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9556 - acc: 0.2655 - val_loss: 1.8397 - val_acc: 0.3012
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9523 - acc: 0.2650 - val_loss: 1.9794 - val_acc: 0.3012
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9682 - acc: 0.2629 - val_loss: 1.7440 - val_acc: 0.3336
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9743 - acc: 0.2606 - val_loss: 2.2530 - val_acc: 0.2162
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9778 - acc: 0.2600 - val_loss: 1.7764 - val_acc: 0.3134
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9916 - acc: 0.2589 - val_loss: 2.2048 - val_acc: 0.2934
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9662 - acc: 0.2590 - val_loss: 1.9989 - val_acc: 0.2628
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9727 - acc: 0.2584 - val_loss: 1.7809 - val_acc: 0.3148
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.9557 - acc: 0.2595 - val_loss: 1.8392 - val_acc: 0.3382
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 1.
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0651 - acc: 0.2217 - val_loss: 2.3191 - val_acc: 0.2172
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0805 - acc: 0.2171 - val_loss: 2.1208 - val_acc: 0.2636
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0792 - acc: 0.2152 - val_loss: 1.8637 - val_acc: 0.2578
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0870 - acc: 0.2122 - val_loss: 1.9309 - val_acc: 0.2412
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0581 - acc: 0.2118 - val_loss: 2.2187 - val_acc: 0.2102
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.1114 - acc: 0.2109 - val_loss: 2.2740 - val_acc: 0.2144
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0651 - acc: 0.2124 - val_loss: 1.8683 - val_acc: 0.2926
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0684 - acc: 0.2120 - val_loss: 1.9003 - val_acc: 0.2740
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0810 - acc: 0.2113 - val_loss: 1.9144 - val_acc: 0.2804
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0605 - acc: 0.2133 - val_loss: 1.9314 - val_acc: 0.2632
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0688 - acc: 0.2099 - val_loss: 1.9014 - val_acc: 0.2512
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0657 - acc: 0.2108 - val_loss: 1.9419 - val_acc: 0.2352
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0736 - acc: 0.2096 - val_loss: 1.8754 - val_acc: 0.2742
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0611 - acc: 0.2125 - val_loss: 2.2881 - val_acc: 0.2290
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0575 - acc: 0.2147 - val_loss: 1.9220 - val_acc: 0.2384
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0552 - acc: 0.2116 - val_loss: 1.9390 - val_acc: 0.2390
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0825 - acc: 0.2154 - val_loss: 1.8885 - val_acc: 0.2808
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0679 - acc: 0.2159 - val_loss: 1.8860 - val_acc: 0.2742
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0669 - acc: 0.2144 - val_loss: 1.8455 - val_acc: 0.2746
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0471 - acc: 0.2161 - val_loss: 1.9153 - val_acc: 0.2626
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0576 - acc: 0.2102 - val_loss: 1.9050 - val_acc: 0.2582
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0500 - acc: 0.2161 - val_loss: 1.8324 - val_acc: 0.2872
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0577 - acc: 0.2147 - val_loss: 2.0640 - val_acc: 0.2286
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0712 - acc: 0.2116 - val_loss: 1.8764 - val_acc: 0.2750
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0741 - acc: 0.2078 - val_loss: 1.8668 - val_acc: 0.2832
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.0676 - acc: 0.2116 - val_loss: 2.2292 - val_acc: 0.2128
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 1.64422
# 45000/45000 - 6s - loss: 2.1128 - acc: 0.2112 - val_loss: 1.8868 - val_acc: 0.2784

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy: ', score[1])
# Out:
#  Test accuracy:  0.2793

# %%
y_hat = model.predict(x_test)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig = plt.figure(figsize=(20, 5))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                color=("green" if pred_idx == true_idx else "red"))
