# %% [markdown]
# <a href="https://colab.research.google.com/github/oyyarko/keras_tut/blob/master/CIFAR10_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.python.keras.datasets import cifar10
import tensorflow.python.keras

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
print(x_train.shape[0])
print(x_test.shape[0])
# Out:
# 50000
# 10000

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20, 5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
from keras.utils import np_utils
import keras

num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

print('X Train shape: ',x_train.shape)

print(x_train.shape[0], 'X Train samples')
print(x_test.shape[0], 'X Test samples')
print(x_valid.shape[0], 'X Valid samples')
# Out:
# X Train shape:  (45000, 32, 32, 3)
# 45000 X Train samples
# 10000 X Test samples
# 5000 X Valid samples
# Using TensorFlow backend.

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 500)               512500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
from tensorflow.python.keras.callbacks import ModelCheckpoint

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)

hist = model.fit(x_train, y_train, batch_size = 32, epochs = 100, verbose=2, callbacks=[checkpointer], validation_data=(x_valid, y_valid), shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.32569, saving model to model.weights.best.hdf5
# 45000/45000 - 12s - loss: 1.5816 - acc: 0.4272 - val_loss: 1.3257 - val_acc: 0.5226
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.32569 to 1.25799, saving model to model.weights.best.hdf5
# 45000/45000 - 6s - loss: 1.2642 - acc: 0.5489 - val_loss: 1.2580 - val_acc: 0.5482
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.25799 to 1.10676, saving model to model.weights.best.hdf5
# 45000/45000 - 6s - loss: 1.1456 - acc: 0.5959 - val_loss: 1.1068 - val_acc: 0.6182
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 1.10676
# 45000/45000 - 6s - loss: 1.0773 - acc: 0.6225 - val_loss: 1.1652 - val_acc: 0.5998
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.10676 to 1.01900, saving model to model.weights.best.hdf5
# 45000/45000 - 6s - loss: 1.0380 - acc: 0.6377 - val_loss: 1.0190 - val_acc: 0.6452
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 1.01900
# 45000/45000 - 6s - loss: 1.0156 - acc: 0.6488 - val_loss: 1.1000 - val_acc: 0.6468
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.01900 to 0.93329, saving model to model.weights.best.hdf5
# 45000/45000 - 6s - loss: 1.0015 - acc: 0.6546 - val_loss: 0.9333 - val_acc: 0.6782
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 0.9960 - acc: 0.6598 - val_loss: 0.9465 - val_acc: 0.6750
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.0098 - acc: 0.6598 - val_loss: 0.9843 - val_acc: 0.6768
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.0126 - acc: 0.6574 - val_loss: 0.9904 - val_acc: 0.6690
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.0216 - acc: 0.6559 - val_loss: 1.2612 - val_acc: 0.6260
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.0358 - acc: 0.6533 - val_loss: 1.0831 - val_acc: 0.6610
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.0464 - acc: 0.6485 - val_loss: 1.1026 - val_acc: 0.6572
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.0637 - acc: 0.6413 - val_loss: 1.0266 - val_acc: 0.6634
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.0862 - acc: 0.6410 - val_loss: 1.2326 - val_acc: 0.6164
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.1060 - acc: 0.6308 - val_loss: 0.9889 - val_acc: 0.6622
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.1198 - acc: 0.6244 - val_loss: 1.0876 - val_acc: 0.6424
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.1412 - acc: 0.6228 - val_loss: 1.4636 - val_acc: 0.5742
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.1615 - acc: 0.6164 - val_loss: 1.3685 - val_acc: 0.5520
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.1819 - acc: 0.6094 - val_loss: 1.1465 - val_acc: 0.6306
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.1988 - acc: 0.6010 - val_loss: 1.0439 - val_acc: 0.6630
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.2167 - acc: 0.6007 - val_loss: 1.0921 - val_acc: 0.6520
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.2415 - acc: 0.5896 - val_loss: 1.3605 - val_acc: 0.5330
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.2533 - acc: 0.5881 - val_loss: 1.2341 - val_acc: 0.5950
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.2748 - acc: 0.5782 - val_loss: 1.1423 - val_acc: 0.6326
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.2972 - acc: 0.5688 - val_loss: 1.2556 - val_acc: 0.5790
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.3184 - acc: 0.5650 - val_loss: 1.3622 - val_acc: 0.5192
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.3281 - acc: 0.5632 - val_loss: 1.3021 - val_acc: 0.5858
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.3517 - acc: 0.5530 - val_loss: 1.3827 - val_acc: 0.6070
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.3778 - acc: 0.5448 - val_loss: 2.6460 - val_acc: 0.4300
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.3619 - acc: 0.5468 - val_loss: 1.1691 - val_acc: 0.6060
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.3792 - acc: 0.5385 - val_loss: 1.1680 - val_acc: 0.5910
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.3989 - acc: 0.5376 - val_loss: 1.1954 - val_acc: 0.6156
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.4021 - acc: 0.5328 - val_loss: 1.2923 - val_acc: 0.5480
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.4151 - acc: 0.5316 - val_loss: 1.2360 - val_acc: 0.5888
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.4713 - acc: 0.5131 - val_loss: 1.4959 - val_acc: 0.5212
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.4551 - acc: 0.5164 - val_loss: 1.3286 - val_acc: 0.5858
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.4595 - acc: 0.5174 - val_loss: 1.2557 - val_acc: 0.5746
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.4820 - acc: 0.5084 - val_loss: 1.2935 - val_acc: 0.5428
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6441 - acc: 0.4372 - val_loss: 1.6068 - val_acc: 0.4280
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6583 - acc: 0.4341 - val_loss: 1.4273 - val_acc: 0.5072
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6523 - acc: 0.4334 - val_loss: 1.4645 - val_acc: 0.4878
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6786 - acc: 0.4271 - val_loss: 1.3897 - val_acc: 0.5050
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6817 - acc: 0.4255 - val_loss: 1.4320 - val_acc: 0.4980
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6793 - acc: 0.4243 - val_loss: 1.5791 - val_acc: 0.4816
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6716 - acc: 0.4301 - val_loss: 1.4194 - val_acc: 0.5200
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6748 - acc: 0.4258 - val_loss: 1.3869 - val_acc: 0.5400
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6797 - acc: 0.4250 - val_loss: 1.4272 - val_acc: 0.5050
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6918 - acc: 0.4248 - val_loss: 1.5128 - val_acc: 0.4528
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6974 - acc: 0.4184 - val_loss: 8.4678 - val_acc: 0.2368
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7206 - acc: 0.4083 - val_loss: 1.6577 - val_acc: 0.4688
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7106 - acc: 0.4130 - val_loss: 1.4695 - val_acc: 0.4718
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7045 - acc: 0.4162 - val_loss: 1.6369 - val_acc: 0.4630
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7211 - acc: 0.4173 - val_loss: 1.5083 - val_acc: 0.4820
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6944 - acc: 0.4146 - val_loss: 1.6520 - val_acc: 0.4658
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6931 - acc: 0.4189 - val_loss: 1.7995 - val_acc: 0.4322
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7008 - acc: 0.4099 - val_loss: 1.8618 - val_acc: 0.4764
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7079 - acc: 0.4095 - val_loss: 1.5335 - val_acc: 0.4764
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.6987 - acc: 0.4086 - val_loss: 1.5745 - val_acc: 0.4016
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7091 - acc: 0.4068 - val_loss: 1.6511 - val_acc: 0.3978
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7208 - acc: 0.4067 - val_loss: 1.4713 - val_acc: 0.5224
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7308 - acc: 0.4020 - val_loss: 1.5074 - val_acc: 0.4532
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7282 - acc: 0.4035 - val_loss: 1.6314 - val_acc: 0.4726
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7305 - acc: 0.3970 - val_loss: 1.7539 - val_acc: 0.4660
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7526 - acc: 0.3917 - val_loss: 1.5503 - val_acc: 0.4392
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.93329
# 45000/45000 - 6s - loss: 1.7428 - acc: 0.3940 - val_loss: 1.5406 - val_acc: 0.4366

# %%
model.load_weights('model.weights.best.hdf5')

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy: ', score[1])
# Out:
#  Test accuracy:  0.6762

# %%
y_hat = model.predict(x_test)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig = plt.figure(figsize=(20, 5))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                color=("green" if pred_idx == true_idx else "red"))
